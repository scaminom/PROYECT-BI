# %%
import numpy as np
from utils.preprocessing import cargar_datos_preprocesados
from utils.model import (crear_modelo, obtener_callbacks, 
                        evaluar_modelo, visualizar_entrenamiento,
                        guardar_modelo)

# Cargar datos preprocesados
print("Cargando datos preprocesados...")
datos = cargar_datos_preprocesados()
# Out:
# Cargando datos preprocesados...

# %%
# Verificar la forma de los datos
print(f"Forma de X_train: {datos['X_train'].shape}")
print(f"Forma de y_train: {datos['y_train'].shape}")
# Out:
# Forma de X_train: (158780, 9)
# Forma de y_train: (158780,)

# %%
# Crear modelo
print("\nCreando modelo...")
model = crear_modelo(datos['X_train'].shape[1])
# Out:
# Creando modelo...
# c:\Users\patri\Documents\workspaces\python\PROYECT-BI\venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Obtener callbacks
callbacks = obtener_callbacks()

# %%
# Entrenar modelo
print("\nIniciando entrenamiento...")
history = model.fit(
    datos['X_train'], 
    datos['y_train'],
    validation_data=(datos['X_test'], datos['y_test']),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Iniciando entrenamiento...
# Epoch 1/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - accuracy: 0.6238 - loss: 1.1274 - val_accuracy: 0.9994 - val_loss: 0.0960 - learning_rate: 0.0010
# Epoch 2/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9318 - loss: 0.2511 - val_accuracy: 0.9519 - val_loss: 0.1333 - learning_rate: 0.0010
# Epoch 3/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9491 - loss: 0.2024 - val_accuracy: 0.9479 - val_loss: 0.1606 - learning_rate: 0.0010
# Epoch 4/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9498 - loss: 0.2054 - val_accuracy: 0.9320 - val_loss: 0.2075 - learning_rate: 0.0010
# Epoch 5/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9489 - loss: 0.2085 - val_accuracy: 0.9997 - val_loss: 0.0740 - learning_rate: 0.0010
# Epoch 6/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9495 - loss: 0.2030 - val_accuracy: 0.9377 - val_loss: 0.1884 - learning_rate: 0.0010
# Epoch 7/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9520 - loss: 0.1972 - val_accuracy: 1.0000 - val_loss: 0.0809 - learning_rate: 0.0010
# Epoch 8/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9506 - loss: 0.2038 - val_accuracy: 0.9664 - val_loss: 0.1462 - learning_rate: 0.0010
# Epoch 9/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9510 - loss: 0.1989 - val_accuracy: 0.9957 - val_loss: 0.1209 - learning_rate: 0.0010
# Epoch 10/100
# 4953/4962 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9544 - loss: 0.1931
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9544 - loss: 0.1931 - val_accuracy: 0.9899 - val_loss: 0.0947 - learning_rate: 0.0010
# Epoch 11/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9749 - loss: 0.1326 - val_accuracy: 0.9278 - val_loss: 0.2060 - learning_rate: 2.0000e-04
# Epoch 12/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9771 - loss: 0.1066 - val_accuracy: 1.0000 - val_loss: 0.0579 - learning_rate: 2.0000e-04
# Epoch 13/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9775 - loss: 0.0988 - val_accuracy: 0.9999 - val_loss: 0.0481 - learning_rate: 2.0000e-04
# Epoch 14/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9785 - loss: 0.0967 - val_accuracy: 0.9408 - val_loss: 0.0922 - learning_rate: 2.0000e-04
# Epoch 15/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9784 - loss: 0.0932 - val_accuracy: 0.9988 - val_loss: 0.0493 - learning_rate: 2.0000e-04
# Epoch 16/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9774 - loss: 0.0943 - val_accuracy: 0.9999 - val_loss: 0.0602 - learning_rate: 2.0000e-04
# Epoch 17/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9787 - loss: 0.0914 - val_accuracy: 1.0000 - val_loss: 0.0390 - learning_rate: 2.0000e-04
# Epoch 18/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9790 - loss: 0.0914 - val_accuracy: 1.0000 - val_loss: 0.0342 - learning_rate: 2.0000e-04
# Epoch 19/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9786 - loss: 0.0909 - val_accuracy: 1.0000 - val_loss: 0.0298 - learning_rate: 2.0000e-04
# Epoch 20/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9801 - loss: 0.0891 - val_accuracy: 1.0000 - val_loss: 0.0345 - learning_rate: 2.0000e-04
# Epoch 21/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9807 - loss: 0.0847 - val_accuracy: 1.0000 - val_loss: 0.0348 - learning_rate: 2.0000e-04
# Epoch 22/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9820 - loss: 0.0815 - val_accuracy: 1.0000 - val_loss: 0.0301 - learning_rate: 2.0000e-04
# Epoch 23/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9788 - loss: 0.0886 - val_accuracy: 0.9834 - val_loss: 0.0566 - learning_rate: 2.0000e-04
# Epoch 24/100
# 4940/4962 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9802 - loss: 0.0833
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001.
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9802 - loss: 0.0833 - val_accuracy: 0.9802 - val_loss: 0.0649 - learning_rate: 2.0000e-04
# Epoch 25/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9844 - loss: 0.0727 - val_accuracy: 1.0000 - val_loss: 0.0462 - learning_rate: 1.0000e-04
# Epoch 26/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9853 - loss: 0.0669 - val_accuracy: 0.9746 - val_loss: 0.0603 - learning_rate: 1.0000e-04
# Epoch 27/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9858 - loss: 0.0641 - val_accuracy: 1.0000 - val_loss: 0.0195 - learning_rate: 1.0000e-04
# Epoch 28/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9857 - loss: 0.0610 - val_accuracy: 1.0000 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 29/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9855 - loss: 0.0620 - val_accuracy: 1.0000 - val_loss: 0.0235 - learning_rate: 1.0000e-04
# Epoch 30/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9845 - loss: 0.0632 - val_accuracy: 1.0000 - val_loss: 0.0224 - learning_rate: 1.0000e-04
# Epoch 31/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9831 - loss: 0.0688 - val_accuracy: 1.0000 - val_loss: 0.0310 - learning_rate: 1.0000e-04
# Epoch 32/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9849 - loss: 0.0638 - val_accuracy: 1.0000 - val_loss: 0.0282 - learning_rate: 1.0000e-04
# Epoch 33/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9839 - loss: 0.0668 - val_accuracy: 0.9875 - val_loss: 0.0543 - learning_rate: 1.0000e-04
# Epoch 34/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9843 - loss: 0.0661 - val_accuracy: 1.0000 - val_loss: 0.0197 - learning_rate: 1.0000e-04
# Epoch 35/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9850 - loss: 0.0644 - val_accuracy: 0.9590 - val_loss: 0.0876 - learning_rate: 1.0000e-04
# Epoch 36/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9840 - loss: 0.0654 - val_accuracy: 1.0000 - val_loss: 0.0246 - learning_rate: 1.0000e-04
# Epoch 37/100
# 4962/4962 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9836 - loss: 0.0671 - val_accuracy: 0.9935 - val_loss: 0.0516 - learning_rate: 1.0000e-04
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 27.

# %%
# Evaluar modelo
print("\nEvaluando modelo...")
evaluar_modelo(model, datos['X_test'], datos['y_test'], 
              datos['label_encoder_y'])
# Out:
# Evaluando modelo...
# 1029/1029 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#
# === Reporte de Clasificación ===
#               precision    recall  f1-score   support
#
#         Fall       1.00      1.00      1.00      7109
#       Spring       1.00      1.00      1.00      9973
#       Summer       1.00      1.00      1.00      7324
#       Winter       1.00      1.00      1.00      8520
#
#     accuracy                           1.00     32926
#    macro avg       1.00      1.00      1.00     32926
# weighted avg       1.00      1.00      1.00     32926

# %%
# Visualizar métricas de entrenamiento
print("\nVisualizando métricas de entrenamiento...")
visualizar_entrenamiento(history)
# Out:
# Visualizando métricas de entrenamiento...

# %%
# Guardar modelo
print("\nGuardando modelo...")
guardar_modelo(model)
        
print("\n¡Entrenamiento completado con éxito!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Guardando modelo...
#
# ¡Entrenamiento completado con éxito!
