# %%
import numpy as np
from utils.preprocessing import cargar_datos_preprocesados
from utils.model import (crear_modelo, obtener_callbacks, 
                        evaluar_modelo, visualizar_entrenamiento,
                        guardar_modelo)

# Cargar datos preprocesados
print("Cargando datos preprocesados...")
datos = cargar_datos_preprocesados()
# Out:
# Cargando datos preprocesados...
#
# === Cargando datos preprocesados ===
# Cargando arrays numpy...
# Cargando encoders...
# Carga completada exitosamente
#
# Dimensiones de los datos:
# X_train: (70016, 12)
# X_test: (19012, 12)

# %%
# Verificar la forma de los datos
print(f"Forma de X_train: {datos['X_train'].shape}")
print(f"Forma de y_train: {datos['y_train'].shape}")
# Out:
# Forma de X_train: (70016, 12)
# Forma de y_train: (70016,)

# %%
# Crear modelo
print("\nCreando modelo...")
model = crear_modelo(datos['X_train'].shape[1])
# Out:
# Creando modelo...
# c:\Users\patri\Documents\workspaces\python\PROYECT-BI\venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Obtener callbacks
callbacks = obtener_callbacks()

# %%
# Entrenar modelo
print("\nIniciando entrenamiento...")
history = model.fit(
    datos['X_train'], 
    datos['y_train'],
    validation_data=(datos['X_test'], datos['y_test']),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Iniciando entrenamiento...
# Epoch 1/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5546 - loss: 1.4126 - val_accuracy: 0.7332 - val_loss: 0.7358 - learning_rate: 0.0010
# Epoch 2/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7196 - loss: 0.7665 - val_accuracy: 0.7441 - val_loss: 0.6524 - learning_rate: 0.0010
# Epoch 3/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7366 - loss: 0.7034 - val_accuracy: 0.7496 - val_loss: 0.6395 - learning_rate: 0.0010
# Epoch 4/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7387 - loss: 0.6919 - val_accuracy: 0.7461 - val_loss: 0.6364 - learning_rate: 0.0010
# Epoch 5/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7385 - loss: 0.6894 - val_accuracy: 0.7506 - val_loss: 0.6295 - learning_rate: 0.0010
# Epoch 6/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7397 - loss: 0.6792 - val_accuracy: 0.7478 - val_loss: 0.6329 - learning_rate: 0.0010
# Epoch 7/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7433 - loss: 0.6817 - val_accuracy: 0.7464 - val_loss: 0.6310 - learning_rate: 0.0010
# Epoch 8/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7434 - loss: 0.6791 - val_accuracy: 0.7485 - val_loss: 0.6279 - learning_rate: 0.0010
# Epoch 9/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7392 - loss: 0.6833 - val_accuracy: 0.7487 - val_loss: 0.6343 - learning_rate: 0.0010
# Epoch 10/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7444 - loss: 0.6729 - val_accuracy: 0.7446 - val_loss: 0.6344 - learning_rate: 0.0010
# Epoch 11/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7411 - loss: 0.6778 - val_accuracy: 0.7448 - val_loss: 0.6373 - learning_rate: 0.0010
# Epoch 12/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7463 - loss: 0.6730 - val_accuracy: 0.7506 - val_loss: 0.6334 - learning_rate: 0.0010
# Epoch 13/100
# 2157/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7441 - loss: 0.6743
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7441 - loss: 0.6744 - val_accuracy: 0.7459 - val_loss: 0.6317 - learning_rate: 0.0010
# Epoch 14/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7436 - loss: 0.6731 - val_accuracy: 0.7549 - val_loss: 0.6134 - learning_rate: 2.0000e-04
# Epoch 15/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7490 - loss: 0.6493 - val_accuracy: 0.7558 - val_loss: 0.6037 - learning_rate: 2.0000e-04
# Epoch 16/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7504 - loss: 0.6495 - val_accuracy: 0.7593 - val_loss: 0.6000 - learning_rate: 2.0000e-04
# Epoch 17/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7542 - loss: 0.6440 - val_accuracy: 0.7561 - val_loss: 0.5990 - learning_rate: 2.0000e-04
# Epoch 18/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7488 - loss: 0.6466 - val_accuracy: 0.7568 - val_loss: 0.5980 - learning_rate: 2.0000e-04
# Epoch 19/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7512 - loss: 0.6477 - val_accuracy: 0.7586 - val_loss: 0.5959 - learning_rate: 2.0000e-04
# Epoch 20/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7483 - loss: 0.6429 - val_accuracy: 0.7612 - val_loss: 0.5958 - learning_rate: 2.0000e-04
# Epoch 21/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7514 - loss: 0.6416 - val_accuracy: 0.7567 - val_loss: 0.5963 - learning_rate: 2.0000e-04
# Epoch 22/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7502 - loss: 0.6454 - val_accuracy: 0.7561 - val_loss: 0.5990 - learning_rate: 2.0000e-04
# Epoch 23/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7528 - loss: 0.6379 - val_accuracy: 0.7588 - val_loss: 0.5937 - learning_rate: 2.0000e-04
# Epoch 24/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7498 - loss: 0.6418 - val_accuracy: 0.7594 - val_loss: 0.5966 - learning_rate: 2.0000e-04
# Epoch 25/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7534 - loss: 0.6355 - val_accuracy: 0.7580 - val_loss: 0.5969 - learning_rate: 2.0000e-04
# Epoch 26/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7512 - loss: 0.6423 - val_accuracy: 0.7585 - val_loss: 0.5942 - learning_rate: 2.0000e-04
# Epoch 27/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7517 - loss: 0.6396 - val_accuracy: 0.7595 - val_loss: 0.5959 - learning_rate: 2.0000e-04
# Epoch 28/100
# 2186/2188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7514 - loss: 0.6349
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001.
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7514 - loss: 0.6349 - val_accuracy: 0.7572 - val_loss: 0.5949 - learning_rate: 2.0000e-04
# Epoch 29/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7535 - loss: 0.6367 - val_accuracy: 0.7592 - val_loss: 0.5894 - learning_rate: 1.0000e-04
# Epoch 30/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7485 - loss: 0.6377 - val_accuracy: 0.7578 - val_loss: 0.5932 - learning_rate: 1.0000e-04
# Epoch 31/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7513 - loss: 0.6409 - val_accuracy: 0.7575 - val_loss: 0.5893 - learning_rate: 1.0000e-04
# Epoch 32/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7551 - loss: 0.6324 - val_accuracy: 0.7592 - val_loss: 0.5893 - learning_rate: 1.0000e-04
# Epoch 33/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7502 - loss: 0.6340 - val_accuracy: 0.7589 - val_loss: 0.5917 - learning_rate: 1.0000e-04
# Epoch 34/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7513 - loss: 0.6397 - val_accuracy: 0.7586 - val_loss: 0.5912 - learning_rate: 1.0000e-04
# Epoch 35/100
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7541 - loss: 0.6315 - val_accuracy: 0.7602 - val_loss: 0.5873 - learning_rate: 1.0000e-04
# Epoch 36/100
#  269/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7517 - loss: 0.6267

# %%
# Evaluar modelo
print("\nEvaluando modelo...")
evaluar_modelo(model, datos['X_test'], datos['y_test'], 
              datos['label_encoder_y'])
# Out:
# Evaluando modelo...
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# === Reporte de Clasificación ===
#               precision    recall  f1-score   support
#
#         Fall       0.71      0.63      0.67      1500
#       Spring       0.64      0.65      0.64      1500
#       Summer       0.77      0.85      0.81      1500
#       Winter       0.87      0.87      0.87      1500
#
#     accuracy                           0.75      6000
#    macro avg       0.75      0.75      0.75      6000
# weighted avg       0.75      0.75      0.75      6000

# %%
# Visualizar métricas de entrenamiento
print("\nVisualizando métricas de entrenamiento...")
visualizar_entrenamiento(history)
# Out:
# Visualizando métricas de entrenamiento...

# %%
# Guardar modelo
print("\nGuardando modelo...")
guardar_modelo(model)
        
print("\n¡Entrenamiento completado con éxito!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Guardando modelo...
#
# ¡Entrenamiento completado con éxito!
