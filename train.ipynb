# %%
import numpy as np
from utils.preprocessing import cargar_datos_preprocesados
from utils.model import (crear_modelo, obtener_callbacks, 
                        evaluar_modelo, visualizar_entrenamiento,
                        guardar_modelo)

# Cargar datos preprocesados
print("Cargando datos preprocesados...")
datos = cargar_datos_preprocesados()
# Out:
# Cargando datos preprocesados...
#
# === Cargando datos preprocesados ===
# Cargando arrays numpy...
# Cargando encoders y nombres de características...
# Carga completada exitosamente
#
# Dimensiones de los datos:
# X_train: (76048, 68)
# X_test: (19012, 68)

# %%
# Verificar la forma de los datos
print(f"Forma de X_train: {datos['X_train'].shape}")
print(f"Forma de y_train: {datos['y_train'].shape}")
# Out:
# Forma de X_train: (76048, 68)
# Forma de y_train: (76048,)

# %%
# Crear modelo
print("\nCreando modelo...")
model = crear_modelo(datos['X_train'].shape[1])
# Out:
# Creando modelo...
# c:\Users\patri\Documents\workspaces\python\PROYECT-BI\venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Obtener callbacks
callbacks = obtener_callbacks()

# %%
# Entrenar modelo
print("\nIniciando entrenamiento...")
history = model.fit(
    datos['X_train'], 
    datos['y_train'],
    validation_data=(datos['X_test'], datos['y_test']),
    epochs=100,
    batch_size=150,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Iniciando entrenamiento...
# Epoch 1/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7119 - loss: 1.6698 - val_accuracy: 0.8992 - val_loss: 0.5438 - learning_rate: 0.0010
# Epoch 2/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8856 - loss: 0.4769 - val_accuracy: 0.9006 - val_loss: 0.3211 - learning_rate: 0.0010
# Epoch 3/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8923 - loss: 0.3393 - val_accuracy: 0.8999 - val_loss: 0.2897 - learning_rate: 0.0010
# Epoch 4/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8936 - loss: 0.3141 - val_accuracy: 0.9037 - val_loss: 0.2764 - learning_rate: 0.0010
# Epoch 5/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8943 - loss: 0.3094 - val_accuracy: 0.9032 - val_loss: 0.2808 - learning_rate: 0.0010
# Epoch 6/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8931 - loss: 0.3055 - val_accuracy: 0.8993 - val_loss: 0.2785 - learning_rate: 0.0010
# Epoch 7/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8939 - loss: 0.3066 - val_accuracy: 0.9047 - val_loss: 0.2698 - learning_rate: 0.0010
# Epoch 8/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8954 - loss: 0.2994 - val_accuracy: 0.9023 - val_loss: 0.2734 - learning_rate: 0.0010
# Epoch 9/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8932 - loss: 0.3048 - val_accuracy: 0.8997 - val_loss: 0.2832 - learning_rate: 0.0010
# Epoch 10/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8964 - loss: 0.2975 - val_accuracy: 0.9031 - val_loss: 0.2677 - learning_rate: 0.0010
# Epoch 11/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8955 - loss: 0.2995 - val_accuracy: 0.9020 - val_loss: 0.2710 - learning_rate: 0.0010
# Epoch 12/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8945 - loss: 0.3031 - val_accuracy: 0.9053 - val_loss: 0.2679 - learning_rate: 0.0010
# Epoch 13/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8969 - loss: 0.2936 - val_accuracy: 0.9075 - val_loss: 0.2611 - learning_rate: 0.0010
# Epoch 14/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8951 - loss: 0.3000 - val_accuracy: 0.9040 - val_loss: 0.2705 - learning_rate: 0.0010
# Epoch 15/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8967 - loss: 0.2981 - val_accuracy: 0.9061 - val_loss: 0.2645 - learning_rate: 0.0010
# Epoch 16/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8942 - loss: 0.3009 - val_accuracy: 0.8992 - val_loss: 0.2720 - learning_rate: 0.0010
# Epoch 17/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8939 - loss: 0.2993 - val_accuracy: 0.9043 - val_loss: 0.2686 - learning_rate: 0.0010
# Epoch 18/100
# 494/507 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8969 - loss: 0.2926
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8969 - loss: 0.2927 - val_accuracy: 0.9023 - val_loss: 0.2709 - learning_rate: 0.0010
# Epoch 19/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9006 - loss: 0.2861 - val_accuracy: 0.9081 - val_loss: 0.2530 - learning_rate: 2.0000e-04
# Epoch 20/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8994 - loss: 0.2765 - val_accuracy: 0.9086 - val_loss: 0.2464 - learning_rate: 2.0000e-04
# Epoch 21/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9017 - loss: 0.2715 - val_accuracy: 0.9066 - val_loss: 0.2470 - learning_rate: 2.0000e-04
# Epoch 22/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9009 - loss: 0.2726 - val_accuracy: 0.9080 - val_loss: 0.2451 - learning_rate: 2.0000e-04
# Epoch 23/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9021 - loss: 0.2677 - val_accuracy: 0.9088 - val_loss: 0.2422 - learning_rate: 2.0000e-04
# Epoch 24/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9008 - loss: 0.2684 - val_accuracy: 0.9088 - val_loss: 0.2412 - learning_rate: 2.0000e-04
# Epoch 25/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9023 - loss: 0.2668 - val_accuracy: 0.9070 - val_loss: 0.2437 - learning_rate: 2.0000e-04
# Epoch 26/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9045 - loss: 0.2638 - val_accuracy: 0.9076 - val_loss: 0.2421 - learning_rate: 2.0000e-04
# Epoch 27/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9028 - loss: 0.2645 - val_accuracy: 0.9069 - val_loss: 0.2422 - learning_rate: 2.0000e-04
# Epoch 28/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9023 - loss: 0.2645 - val_accuracy: 0.9085 - val_loss: 0.2397 - learning_rate: 2.0000e-04
# Epoch 29/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9022 - loss: 0.2652 - val_accuracy: 0.9072 - val_loss: 0.2429 - learning_rate: 2.0000e-04
# Epoch 30/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9023 - loss: 0.2623 - val_accuracy: 0.9073 - val_loss: 0.2409 - learning_rate: 2.0000e-04
# Epoch 31/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9029 - loss: 0.2636 - val_accuracy: 0.9091 - val_loss: 0.2390 - learning_rate: 2.0000e-04
# Epoch 32/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9014 - loss: 0.2626 - val_accuracy: 0.9070 - val_loss: 0.2417 - learning_rate: 2.0000e-04
# Epoch 33/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9019 - loss: 0.2621 - val_accuracy: 0.9075 - val_loss: 0.2413 - learning_rate: 2.0000e-04
# Epoch 34/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9033 - loss: 0.2603 - val_accuracy: 0.9071 - val_loss: 0.2398 - learning_rate: 2.0000e-04
# Epoch 35/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9032 - loss: 0.2600 - val_accuracy: 0.9091 - val_loss: 0.2396 - learning_rate: 2.0000e-04
# Epoch 36/100
# 500/507 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9021 - loss: 0.2637
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001.
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9021 - loss: 0.2637 - val_accuracy: 0.9086 - val_loss: 0.2399 - learning_rate: 2.0000e-04
# Epoch 37/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9035 - loss: 0.2596 - val_accuracy: 0.9083 - val_loss: 0.2384 - learning_rate: 1.0000e-04
# Epoch 38/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9042 - loss: 0.2565 - val_accuracy: 0.9091 - val_loss: 0.2369 - learning_rate: 1.0000e-04
# Epoch 39/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9042 - loss: 0.2563 - val_accuracy: 0.9086 - val_loss: 0.2371 - learning_rate: 1.0000e-04
# Epoch 40/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9053 - loss: 0.2527 - val_accuracy: 0.9094 - val_loss: 0.2374 - learning_rate: 1.0000e-04
# Epoch 41/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9042 - loss: 0.2574 - val_accuracy: 0.9081 - val_loss: 0.2373 - learning_rate: 1.0000e-04
# Epoch 42/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9039 - loss: 0.2556 - val_accuracy: 0.9090 - val_loss: 0.2362 - learning_rate: 1.0000e-04
# Epoch 43/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9044 - loss: 0.2555 - val_accuracy: 0.9098 - val_loss: 0.2349 - learning_rate: 1.0000e-04
# Epoch 44/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9051 - loss: 0.2550 - val_accuracy: 0.9080 - val_loss: 0.2368 - learning_rate: 1.0000e-04
# Epoch 45/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9034 - loss: 0.2552 - val_accuracy: 0.9093 - val_loss: 0.2369 - learning_rate: 1.0000e-04
# Epoch 46/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9044 - loss: 0.2527 - val_accuracy: 0.9083 - val_loss: 0.2365 - learning_rate: 1.0000e-04
# Epoch 47/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9063 - loss: 0.2521 - val_accuracy: 0.9096 - val_loss: 0.2353 - learning_rate: 1.0000e-04
# Epoch 48/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9042 - loss: 0.2539 - val_accuracy: 0.9101 - val_loss: 0.2348 - learning_rate: 1.0000e-04
# Epoch 49/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9046 - loss: 0.2553 - val_accuracy: 0.9075 - val_loss: 0.2369 - learning_rate: 1.0000e-04
# Epoch 50/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9040 - loss: 0.2549 - val_accuracy: 0.9079 - val_loss: 0.2359 - learning_rate: 1.0000e-04
# Epoch 51/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9054 - loss: 0.2541 - val_accuracy: 0.9078 - val_loss: 0.2358 - learning_rate: 1.0000e-04
# Epoch 52/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9025 - loss: 0.2568 - val_accuracy: 0.9081 - val_loss: 0.2346 - learning_rate: 1.0000e-04
# Epoch 53/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9033 - loss: 0.2540 - val_accuracy: 0.9089 - val_loss: 0.2370 - learning_rate: 1.0000e-04
# Epoch 54/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9049 - loss: 0.2526 - val_accuracy: 0.9079 - val_loss: 0.2364 - learning_rate: 1.0000e-04
# Epoch 55/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9042 - loss: 0.2562 - val_accuracy: 0.9092 - val_loss: 0.2354 - learning_rate: 1.0000e-04
# Epoch 56/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9042 - loss: 0.2562 - val_accuracy: 0.9086 - val_loss: 0.2357 - learning_rate: 1.0000e-04
# Epoch 57/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9053 - loss: 0.2533 - val_accuracy: 0.9083 - val_loss: 0.2343 - learning_rate: 1.0000e-04
# Epoch 58/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9057 - loss: 0.2532 - val_accuracy: 0.9097 - val_loss: 0.2349 - learning_rate: 1.0000e-04
# Epoch 59/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9065 - loss: 0.2523 - val_accuracy: 0.9088 - val_loss: 0.2343 - learning_rate: 1.0000e-04
# Epoch 60/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9033 - loss: 0.2549 - val_accuracy: 0.9095 - val_loss: 0.2343 - learning_rate: 1.0000e-04
# Epoch 61/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9048 - loss: 0.2535 - val_accuracy: 0.9085 - val_loss: 0.2357 - learning_rate: 1.0000e-04
# Epoch 62/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9065 - loss: 0.2510 - val_accuracy: 0.9086 - val_loss: 0.2371 - learning_rate: 1.0000e-04
# Epoch 63/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9046 - loss: 0.2567 - val_accuracy: 0.9091 - val_loss: 0.2366 - learning_rate: 1.0000e-04
# Epoch 64/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9068 - loss: 0.2478 - val_accuracy: 0.9068 - val_loss: 0.2370 - learning_rate: 1.0000e-04
# Epoch 65/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9057 - loss: 0.2536 - val_accuracy: 0.9069 - val_loss: 0.2385 - learning_rate: 1.0000e-04
# Epoch 66/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9035 - loss: 0.2546 - val_accuracy: 0.9090 - val_loss: 0.2363 - learning_rate: 1.0000e-04
# Epoch 67/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9051 - loss: 0.2508 - val_accuracy: 0.9058 - val_loss: 0.2380 - learning_rate: 1.0000e-04
# Epoch 68/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9038 - loss: 0.2562 - val_accuracy: 0.9082 - val_loss: 0.2345 - learning_rate: 1.0000e-04
# Epoch 69/100
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9048 - loss: 0.2533 - val_accuracy: 0.9076 - val_loss: 0.2369 - learning_rate: 1.0000e-04
# Epoch 69: early stopping
# Restoring model weights from the end of the best epoch: 59.

# %%
# Evaluar modelo
print("\nEvaluando modelo...")
evaluar_modelo(model, datos['X_test'], datos['y_test'], 
              datos['label_encoder_y'])
# Out:
# Evaluando modelo...
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#
# === Reporte de Clasificación ===
#               precision    recall  f1-score   support
#
#         Fall       0.83      0.86      0.85      3802
#       Spring       0.85      0.82      0.83      2852
#       Summer       0.95      0.95      0.95      5704
#       Winter       0.95      0.94      0.94      6654
#
#     accuracy                           0.91     19012
#    macro avg       0.89      0.89      0.89     19012
# weighted avg       0.91      0.91      0.91     19012

# %%
# Visualizar métricas de entrenamiento
print("\nVisualizando métricas de entrenamiento...")
visualizar_entrenamiento(history)
# Out:
# Visualizando métricas de entrenamiento...

# %%
# Guardar modelo
print("\nGuardando modelo...")
guardar_modelo(model)
        
print("\n¡Entrenamiento completado con éxito!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Guardando modelo...
#
# ¡Entrenamiento completado con éxito!
