# %%
import numpy as np
from utils.preprocessing import cargar_datos_preprocesados
from utils.model import (crear_modelo, obtener_callbacks, 
                        evaluar_modelo, visualizar_entrenamiento,
                        guardar_modelo)

# Cargar datos preprocesados
print("Cargando datos preprocesados...")
datos = cargar_datos_preprocesados()
# Out:
# Cargando datos preprocesados...

# %%
# Verificar la forma de los datos
print(f"Forma de X_train: {datos['X_train'].shape}")
print(f"Forma de y_train: {datos['y_train'].shape}")
# Out:
# Forma de X_train: (292516, 13)
# Forma de y_train: (292516,)

# %%
# Crear modelo
print("\nCreando modelo...")
model = crear_modelo(datos['X_train'].shape[1])
# Out:
# Creando modelo...
# c:\Users\scaminom.SEBAS\Documents\UTA\BI\Segundo Parcial\Neural Network\neural-network\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Obtener callbacks
callbacks = obtener_callbacks()

# %%
# Entrenar modelo
print("\nIniciando entrenamiento...")
history = model.fit(
    datos['X_train'], 
    datos['y_train'],
    validation_data=(datos['X_test'], datos['y_test']),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Iniciando entrenamiento...
# Epoch 1/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.7139 - loss: 0.9279 - val_accuracy: 0.8911 - val_loss: 0.3458 - learning_rate: 0.0010
# Epoch 2/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.8681 - loss: 0.4002 - val_accuracy: 0.9005 - val_loss: 0.3062 - learning_rate: 0.0010
# Epoch 3/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.8775 - loss: 0.3836 - val_accuracy: 0.9217 - val_loss: 0.2711 - learning_rate: 0.0010
# Epoch 4/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.8810 - loss: 0.3753 - val_accuracy: 0.9197 - val_loss: 0.2837 - learning_rate: 0.0010
# Epoch 5/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.8783 - loss: 0.3832 - val_accuracy: 0.9061 - val_loss: 0.2956 - learning_rate: 0.0010
# Epoch 6/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.8801 - loss: 0.3788 - val_accuracy: 0.8943 - val_loss: 0.3089 - learning_rate: 0.0010
# Epoch 7/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.8808 - loss: 0.3789 - val_accuracy: 0.9169 - val_loss: 0.2808 - learning_rate: 0.0010
# Epoch 8/100
# 9132/9142 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8796 - loss: 0.3800
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.8796 - loss: 0.3800 - val_accuracy: 0.9131 - val_loss: 0.2712 - learning_rate: 0.0010
# Epoch 9/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9080 - loss: 0.3093 - val_accuracy: 0.9462 - val_loss: 0.1987 - learning_rate: 2.0000e-04
# Epoch 10/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9145 - loss: 0.2798 - val_accuracy: 0.9481 - val_loss: 0.1889 - learning_rate: 2.0000e-04
# Epoch 11/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9152 - loss: 0.2741 - val_accuracy: 0.9373 - val_loss: 0.2095 - learning_rate: 2.0000e-04
# Epoch 12/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.9156 - loss: 0.2704 - val_accuracy: 0.9501 - val_loss: 0.1787 - learning_rate: 2.0000e-04
# Epoch 13/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.9134 - loss: 0.2736 - val_accuracy: 0.9458 - val_loss: 0.1925 - learning_rate: 2.0000e-04
# Epoch 14/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.9159 - loss: 0.2657 - val_accuracy: 0.9522 - val_loss: 0.1747 - learning_rate: 2.0000e-04
# Epoch 15/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9147 - loss: 0.2678 - val_accuracy: 0.9308 - val_loss: 0.2036 - learning_rate: 2.0000e-04
# Epoch 16/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9133 - loss: 0.2679 - val_accuracy: 0.9529 - val_loss: 0.1674 - learning_rate: 2.0000e-04
# Epoch 17/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9155 - loss: 0.2639 - val_accuracy: 0.9446 - val_loss: 0.1778 - learning_rate: 2.0000e-04
# Epoch 18/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9144 - loss: 0.2640 - val_accuracy: 0.9476 - val_loss: 0.1742 - learning_rate: 2.0000e-04
# Epoch 19/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9161 - loss: 0.2622 - val_accuracy: 0.9506 - val_loss: 0.1822 - learning_rate: 2.0000e-04
# Epoch 20/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9145 - loss: 0.2637 - val_accuracy: 0.9516 - val_loss: 0.1747 - learning_rate: 2.0000e-04
# Epoch 21/100
# 9139/9142 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9170 - loss: 0.2579
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001.
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9170 - loss: 0.2579 - val_accuracy: 0.9405 - val_loss: 0.1800 - learning_rate: 2.0000e-04
# Epoch 22/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9216 - loss: 0.2468 - val_accuracy: 0.9563 - val_loss: 0.1562 - learning_rate: 1.0000e-04
# Epoch 23/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9215 - loss: 0.2444 - val_accuracy: 0.9551 - val_loss: 0.1555 - learning_rate: 1.0000e-04
# Epoch 24/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9232 - loss: 0.2419 - val_accuracy: 0.9553 - val_loss: 0.1605 - learning_rate: 1.0000e-04
# Epoch 25/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9230 - loss: 0.2398 - val_accuracy: 0.9556 - val_loss: 0.1533 - learning_rate: 1.0000e-04
# Epoch 26/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9232 - loss: 0.2397 - val_accuracy: 0.9511 - val_loss: 0.1643 - learning_rate: 1.0000e-04
# Epoch 27/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9242 - loss: 0.2369 - val_accuracy: 0.9551 - val_loss: 0.1601 - learning_rate: 1.0000e-04
# Epoch 28/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9234 - loss: 0.2383 - val_accuracy: 0.9577 - val_loss: 0.1504 - learning_rate: 1.0000e-04
# Epoch 29/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9236 - loss: 0.2383 - val_accuracy: 0.9540 - val_loss: 0.1608 - learning_rate: 1.0000e-04
# Epoch 30/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9232 - loss: 0.2362 - val_accuracy: 0.9527 - val_loss: 0.1585 - learning_rate: 1.0000e-04
# Epoch 31/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9250 - loss: 0.2337 - val_accuracy: 0.9599 - val_loss: 0.1478 - learning_rate: 1.0000e-04
# Epoch 32/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9233 - loss: 0.2339 - val_accuracy: 0.9512 - val_loss: 0.1618 - learning_rate: 1.0000e-04
# Epoch 33/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9226 - loss: 0.2353 - val_accuracy: 0.9517 - val_loss: 0.1659 - learning_rate: 1.0000e-04
# Epoch 34/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9234 - loss: 0.2348 - val_accuracy: 0.9541 - val_loss: 0.1578 - learning_rate: 1.0000e-04
# Epoch 35/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9237 - loss: 0.2354 - val_accuracy: 0.9568 - val_loss: 0.1537 - learning_rate: 1.0000e-04
# Epoch 36/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9232 - loss: 0.2344 - val_accuracy: 0.9597 - val_loss: 0.1522 - learning_rate: 1.0000e-04
# Epoch 37/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9235 - loss: 0.2329 - val_accuracy: 0.9541 - val_loss: 0.1511 - learning_rate: 1.0000e-04
# Epoch 38/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.9234 - loss: 0.2351 - val_accuracy: 0.9476 - val_loss: 0.1667 - learning_rate: 1.0000e-04
# Epoch 39/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.9235 - loss: 0.2339 - val_accuracy: 0.9560 - val_loss: 0.1499 - learning_rate: 1.0000e-04
# Epoch 40/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.9233 - loss: 0.2346 - val_accuracy: 0.9569 - val_loss: 0.1544 - learning_rate: 1.0000e-04
# Epoch 41/100
# 9142/9142 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9237 - loss: 0.2354 - val_accuracy: 0.9519 - val_loss: 0.1558 - learning_rate: 1.0000e-04
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 31.

# %%
# Evaluar modelo
print("\nEvaluando modelo...")
evaluar_modelo(model, datos['X_test'], datos['y_test'], 
              datos['label_encoder_y'])
# Out:
# Evaluando modelo...
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 1s 883us/step
#
# === Reporte de Clasificación ===
#                     precision    recall  f1-score   support
#
#  Alta_Rentabilidad       0.97      0.95      0.96     10890
#  Baja_Rentabilidad       0.97      0.97      0.97     18621
#            Perdida       0.99      0.97      0.98     11798
# Rentabilidad_Media       0.83      0.93      0.88      4974
#
#           accuracy                           0.96     46283
#          macro avg       0.94      0.95      0.95     46283
#       weighted avg       0.96      0.96      0.96     46283

# %%
# Visualizar métricas de entrenamiento
print("\nVisualizando métricas de entrenamiento...")
visualizar_entrenamiento(history)
# Out:
# Visualizando métricas de entrenamiento...

# %%
# Guardar modelo
print("\nGuardando modelo...")
guardar_modelo(model)
        
print("\n¡Entrenamiento completado con éxito!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Guardando modelo...
#
# ¡Entrenamiento completado con éxito!
