# %%
import numpy as np
from utils.preprocessing import cargar_datos_preprocesados
from utils.model import (crear_modelo, obtener_callbacks, 
                        evaluar_modelo, visualizar_entrenamiento,
                        guardar_modelo)

# Cargar datos preprocesados
print("Cargando datos preprocesados...")
datos = cargar_datos_preprocesados()
# Out:
# Cargando datos preprocesados...
#
# === Cargando datos preprocesados ===
# Cargando arrays numpy...
# Cargando encoders...
# Carga completada exitosamente
#
# Dimensiones de los datos:
# X_train: (105376, 10)
# X_test: (19012, 10)

# %%
# Verificar la forma de los datos
print(f"Forma de X_train: {datos['X_train'].shape}")
print(f"Forma de y_train: {datos['y_train'].shape}")
# Out:
# Forma de X_train: (105376, 10)
# Forma de y_train: (105376,)

# %%
# Crear modelo
print("\nCreando modelo...")
model = crear_modelo(datos['X_train'].shape[1])
# Out:
# Creando modelo...
# c:\Users\patri\Documents\workspaces\python\PROYECT-BI\venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Obtener callbacks
callbacks = obtener_callbacks()

# %%
# Entrenar modelo
print("\nIniciando entrenamiento...")
history = model.fit(
    datos['X_train'], 
    datos['y_train'],
    validation_data=(datos['X_test'], datos['y_test']),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Iniciando entrenamiento...
# Epoch 1/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.6097 - loss: 1.2090 - val_accuracy: 0.8490 - val_loss: 0.4202 - learning_rate: 0.0010
# Epoch 2/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.7972 - loss: 0.5684 - val_accuracy: 0.8560 - val_loss: 0.4020 - learning_rate: 0.0010
# Epoch 3/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8047 - loss: 0.5396 - val_accuracy: 0.8488 - val_loss: 0.3892 - learning_rate: 0.0010
# Epoch 4/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8068 - loss: 0.5328 - val_accuracy: 0.8663 - val_loss: 0.3695 - learning_rate: 0.0010
# Epoch 5/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8068 - loss: 0.5252 - val_accuracy: 0.8506 - val_loss: 0.3858 - learning_rate: 0.0010
# Epoch 6/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8091 - loss: 0.5224 - val_accuracy: 0.8631 - val_loss: 0.3748 - learning_rate: 0.0010
# Epoch 7/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8109 - loss: 0.5155 - val_accuracy: 0.8667 - val_loss: 0.3706 - learning_rate: 0.0010
# Epoch 8/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8106 - loss: 0.5167 - val_accuracy: 0.8687 - val_loss: 0.3759 - learning_rate: 0.0010
# Epoch 9/100
# 3286/3293 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8131 - loss: 0.5158
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8131 - loss: 0.5158 - val_accuracy: 0.8685 - val_loss: 0.3707 - learning_rate: 0.0010
# Epoch 10/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8198 - loss: 0.4931 - val_accuracy: 0.8707 - val_loss: 0.3510 - learning_rate: 2.0000e-04
# Epoch 11/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8190 - loss: 0.4898 - val_accuracy: 0.8710 - val_loss: 0.3497 - learning_rate: 2.0000e-04
# Epoch 12/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8204 - loss: 0.4811 - val_accuracy: 0.8727 - val_loss: 0.3489 - learning_rate: 2.0000e-04
# Epoch 13/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8208 - loss: 0.4823 - val_accuracy: 0.8723 - val_loss: 0.3474 - learning_rate: 2.0000e-04
# Epoch 14/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8211 - loss: 0.4798 - val_accuracy: 0.8593 - val_loss: 0.3481 - learning_rate: 2.0000e-04
# Epoch 15/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8201 - loss: 0.4785 - val_accuracy: 0.8668 - val_loss: 0.3473 - learning_rate: 2.0000e-04
# Epoch 16/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8199 - loss: 0.4814 - val_accuracy: 0.8546 - val_loss: 0.3486 - learning_rate: 2.0000e-04
# Epoch 17/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8174 - loss: 0.4780 - val_accuracy: 0.8686 - val_loss: 0.3431 - learning_rate: 2.0000e-04
# Epoch 18/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8187 - loss: 0.4818 - val_accuracy: 0.8525 - val_loss: 0.3515 - learning_rate: 2.0000e-04
# Epoch 19/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8191 - loss: 0.4801 - val_accuracy: 0.8703 - val_loss: 0.3442 - learning_rate: 2.0000e-04
# Epoch 20/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8215 - loss: 0.4729 - val_accuracy: 0.8545 - val_loss: 0.3456 - learning_rate: 2.0000e-04
# Epoch 21/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8232 - loss: 0.4739 - val_accuracy: 0.8597 - val_loss: 0.3470 - learning_rate: 2.0000e-04
# Epoch 22/100
# 3277/3293 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8200 - loss: 0.4786
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001.
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8200 - loss: 0.4786 - val_accuracy: 0.8573 - val_loss: 0.3446 - learning_rate: 2.0000e-04
# Epoch 23/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8224 - loss: 0.4728 - val_accuracy: 0.8694 - val_loss: 0.3403 - learning_rate: 1.0000e-04
# Epoch 24/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8227 - loss: 0.4721 - val_accuracy: 0.8622 - val_loss: 0.3432 - learning_rate: 1.0000e-04
# Epoch 25/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8239 - loss: 0.4687 - val_accuracy: 0.8622 - val_loss: 0.3451 - learning_rate: 1.0000e-04
# Epoch 26/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8243 - loss: 0.4683 - val_accuracy: 0.8675 - val_loss: 0.3404 - learning_rate: 1.0000e-04
# Epoch 27/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8211 - loss: 0.4755 - val_accuracy: 0.8675 - val_loss: 0.3369 - learning_rate: 1.0000e-04
# Epoch 28/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8248 - loss: 0.4670 - val_accuracy: 0.8578 - val_loss: 0.3426 - learning_rate: 1.0000e-04
# Epoch 29/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8243 - loss: 0.4668 - val_accuracy: 0.8661 - val_loss: 0.3422 - learning_rate: 1.0000e-04
# Epoch 30/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8251 - loss: 0.4670 - val_accuracy: 0.8706 - val_loss: 0.3408 - learning_rate: 1.0000e-04
# Epoch 31/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8221 - loss: 0.4712 - val_accuracy: 0.8746 - val_loss: 0.3332 - learning_rate: 1.0000e-04
# Epoch 32/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8217 - loss: 0.4745 - val_accuracy: 0.8582 - val_loss: 0.3477 - learning_rate: 1.0000e-04
# Epoch 33/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8212 - loss: 0.4694 - val_accuracy: 0.8603 - val_loss: 0.3374 - learning_rate: 1.0000e-04
# Epoch 34/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8236 - loss: 0.4667 - val_accuracy: 0.8735 - val_loss: 0.3341 - learning_rate: 1.0000e-04
# Epoch 35/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8243 - loss: 0.4660 - val_accuracy: 0.8652 - val_loss: 0.3367 - learning_rate: 1.0000e-04
# Epoch 36/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8225 - loss: 0.4699 - val_accuracy: 0.8575 - val_loss: 0.3442 - learning_rate: 1.0000e-04
# Epoch 37/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8219 - loss: 0.4701 - val_accuracy: 0.8524 - val_loss: 0.3487 - learning_rate: 1.0000e-04
# Epoch 38/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8211 - loss: 0.4661 - val_accuracy: 0.8667 - val_loss: 0.3409 - learning_rate: 1.0000e-04
# Epoch 39/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8220 - loss: 0.4705 - val_accuracy: 0.8709 - val_loss: 0.3346 - learning_rate: 1.0000e-04
# Epoch 40/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8249 - loss: 0.4637 - val_accuracy: 0.8627 - val_loss: 0.3403 - learning_rate: 1.0000e-04
# Epoch 41/100
# 3293/3293 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8229 - loss: 0.4681 - val_accuracy: 0.8655 - val_loss: 0.3391 - learning_rate: 1.0000e-04
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 31.

# %%
# Evaluar modelo
print("\nEvaluando modelo...")
evaluar_modelo(model, datos['X_test'], datos['y_test'], 
              datos['label_encoder_y'])
# Out:
# Evaluando modelo...
# 595/595 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#
# === Reporte de Clasificación ===
#               precision    recall  f1-score   support
#
#         Fall       0.80      0.77      0.78      3802
#       Spring       0.71      0.82      0.76      2852
#       Summer       0.95      0.91      0.93      5704
#       Winter       0.94      0.93      0.94      6654
#
#     accuracy                           0.87     19012
#    macro avg       0.85      0.86      0.85     19012
# weighted avg       0.88      0.87      0.88     19012

# %%
# Visualizar métricas de entrenamiento
print("\nVisualizando métricas de entrenamiento...")
visualizar_entrenamiento(history)
# Out:
# Visualizando métricas de entrenamiento...

# %%
# Guardar modelo
print("\nGuardando modelo...")
guardar_modelo(model)
        
print("\n¡Entrenamiento completado con éxito!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Guardando modelo...
#
# ¡Entrenamiento completado con éxito!
